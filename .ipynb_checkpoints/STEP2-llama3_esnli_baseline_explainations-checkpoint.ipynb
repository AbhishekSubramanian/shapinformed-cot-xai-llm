# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from tqdm.auto import tqdm
import time
import gc  # Garbage collector

# %%
# --- Configuration ---
model_name = "meta-llama/Llama-3.1-8B-Instruct"
access_token = ""  # Replace with your token

# Max tokens for the generated *explanation* (adjust as needed)
max_explanation_length = 75
# Path to your saved correct results (adjust if needed)
correct_results_file = '/content/llama3_nli_analysis_500_shap_correct.csv'
# Output file path
output_file = 'results_correct_with_explanations.csv'

# --- Load Model and Tokenizer ---
print("Loading model and tokenizer...")
# Ensure tokenizer is loaded correctly
tokenizer = AutoTokenizer.from_pretrained(model_name, token=access_token)
if tokenizer.pad_token is None:
    print("Setting pad_token to eos_token")
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left" # Important for Causal LM generation

# Load model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    token=access_token,
    torch_dtype=torch.float16, # Use float16 for efficiency
    device_map="auto" # Automatically distribute across available devices (GPU/CPU)
)
model.eval() # Set model to evaluation mode
print("Model and tokenizer loaded.")
# Out:
# Loading model and tokenizer...
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Setting pad_token to eos_token
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Model and tokenizer loaded.

# %%
# --- Helper Function for Generation ---
def generate_model_explanation(prompt, max_new_tokens):
    """Generates text using the loaded model."""
    inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, max_length=tokenizer.model_max_length - max_new_tokens).to(model.device)

    # Ensure attention_mask is passed if padding is used
    attention_mask = inputs.attention_mask

    # Clear GPU cache before generation if using GPU
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Generate output
    with torch.no_grad():
      outputs = model.generate(
        inputs.input_ids,
        attention_mask=attention_mask,
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id, # Make sure EOS token is considered

        # --- CHANGES START HERE ---
        do_sample=True,         # Enable sampling
        temperature=0.0,        # Adjust temperature (e.g., 0.6-0.9)
        top_k=50,               # Consider top K tokens
        # top_p=0.9,            # Alternatively, use top_p nucleus sampling
        repetition_penalty=1.15 # Penalize repetition (e.g., 1.1-1.2)
        # --- CHANGES END HERE ---
    )

    # Decode the generated tokens, skipping special tokens and the input prompt
    # We want only the newly generated part
    input_length = inputs.input_ids.shape[1]
    generated_ids = outputs[0, input_length:]
    explanation = tokenizer.decode(generated_ids, skip_special_tokens=True)

    # Basic cleaning
    explanation = explanation.strip()

    # Clear GPU cache after generation
    del inputs, outputs
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect() # Force garbage collection

    return explanation

# %%
# --- Load Data ---
print(f"Loading correct results from {correct_results_file}...")
try:
    df_correct = pd.read_csv(correct_results_file)
    # Handle potential loading issues if 'shap_value' was complex
    if 'shap_value' in df_correct.columns:
         # Example: If shap_value needs literal_eval, uncomment below
         # import ast
         # df_correct['shap_value'] = df_correct['shap_value'].apply(ast.literal_eval)
         pass # Add specific handling if needed based on how shap_value was saved
except FileNotFoundError:
    print(f"Error: File not found at {correct_results_file}")
    print("Please ensure the file exists or modify the 'correct_results_file' variable.")
    exit()
except Exception as e:
    print(f"Error loading CSV: {e}")
    exit()

print(f"Loaded {len(df_correct)} correctly classified samples.")
# Out:
# Loading correct results from /content/llama3_nli_analysis_500_shap_correct.csv...
# Loaded 179 correctly classified samples.

# %%
# --- Generate Explanations ---
model_explanations = []
print(f"Generating model explanations (max_new_tokens={max_explanation_length})...")
start_time = time.time()

# Use tqdm for progress bar
for index, row in tqdm(df_correct.iterrows(), total=df_correct.shape[0], desc="Generating Explanations"):
    premise = row['premise']
    hypothesis = row['hypothesis']
    # Use 'pred_label' as it's confirmed correct for this dataframe
    predicted_label = row['pred_label']

    # Construct the prompt for explanation
    explanation_prompt = f"""Premise: {premise}
Hypothesis: {hypothesis}
Classification: {predicted_label}

Reasoning for this classification:"""

    # Generate the explanation
    explanation = generate_model_explanation(explanation_prompt, max_new_tokens=max_explanation_length)
    model_explanations.append(explanation)
    print(explanation)

    # Optional: Print progress periodically
    print(f"Processed {index + 1}/{len(df_correct)} samples...")
# Out:
# Generating model explanations (max_new_tokens=75)...
# Generating Explanations:   0%|          | 0/179 [00:00<?, ?it/s]
# Both of the premises imply that there is no man inside.
#
# This problem has been solved!
#
# ## Comments (0)
#
# Sorry, I don't understand what you mean by "the two women are embracing". Are they kissing? And if so, why?
#
# The hypothesis isn't correct. If we assume both people hold on to their bags and it's just one person standing in front
# Processed 1/179 samples...
# The two numbers represent different teams. It is implied that they were playing some sort of sport.
#
# Example sentences:
#
# • (A) A basketball game between two schools was played at an indoor arena.
# • (B) Both teams had red shirts.
# • (C) Only team B won the game.
# • (D) Team B scored more goals than team A during the game
# Processed 2/179 samples...
# I have not yet written down all my thoughts on the matter, but if I were to guess (and it is just an educated guess), there are two main things that would explain why "A man selling donuts" entails "a customer". One thing being that both terms can be used interchangeably. The other one could possibly be because of the similarity between the word "
# Processed 3/179 samples...
# the definition is quite clear. The only question I have here is whether it's a good way to classify these two items.
#
# If you ask me, I'd say yes; because they are not exactly like in any other way (not just from the point of view of clothing). They both wear helmets and shoulder pads - so that part is covered by "protective" category
# Processed 4/179 samples...
# The premise implies that the dogs are in the same position as each other. However, it does not say anything about their relative positions within their respective groups.
#
# This is a typical example where there exists an inference from one premises to another which can be justified by stating that they are both true. There may be no reason why these two statements must be related (in this case)
# Processed 5/179 samples...
# The man appears to be smiling, and the location suggests that it's indoors. In addition, his eyes are not focused on anything specific.
#
# I'm pretty sure he was just smiling at me while I drove by (maybe even when we were passing each other)
# Processed 6/179 samples...
# I think that it's obvious, but I wanted to be sure.
#
# • The hypothesis states two things:
#
# 1. $a$ and $b$ are both colors.
# 2. It's possible that they're not the same color.
#
# The first statement can't possibly be true because if we look at an object as being either red or green (for example) then there would
# Processed 7/179 samples...
# It seems plausible that a person would try to reach out and touch something they could see in front of them.
#
# Evidence for this hypothesis:
#
# • The word “propeller” (which refers to an object attached to the wing or tailplane of an airplane) comes from the Latin prōpelle, meaning "to pull forward" — i.e., to propel. So it
# Processed 8/179 samples...
# The object being touched seems quite large and interesting. There are no other objects in sight.
#
# Explanation: I have always thought that there was something fascinating about planes, because they seem so complex yet still function well even when not flying. When I look at them from above, it looks like an oval shape but from below you see how they curve into an arch before flattening out
# Processed 9/179 samples...
# I was trying to figure out how it could be an entailment and came up with a bunch of possibilities. However, they didn't feel right.
#
# The only possible candidate that felt correct (to me) was "a man can do a cartwheel." That's because one way you can think about entailing something is as being able to make a claim. In fact,
# Processed 10/179 samples...
# The premises are contradictory, so there's no way she can be both.
# Processed 11/179 samples...
# I am assuming that we have two statements:
# • $p$: The woman did a cartwheel
# • $\neg p$ : The woman fell on her head.
#
# I believe, then, that it's impossible for both of these to be true. This is because if the first statement were false (the woman didn't do a cartwheel), she would not fall on her
# Processed 12/179 samples...
# We can see that the bike is not being ridden by any of the people we have seen. So it must be excluded from their choices.
#
# Conclusion: The only person who could ride a bicycle would have to do so while walking, but since they're already standing there and holding signs (they aren't doing anything), I'm assuming that's impossible.
#
# Commentary: Since someone
# Processed 13/179 samples...
# The statement implies that the child is thinking about the ball. This would be a typical example of an entailment, since it could not be true without having some content.
#
# This reasoning should only be used as a quick check to see if something seems correct or incorrect before you proceed with your proof.
# Processed 14/179 samples...
# "People" is not identical with "family". I believe that the only way we can be certain about whether or not two things belong together is if there exists some property, such as identity. However, there isn't any such thing as 'identity' between families and people.
#
# I don't think it's even possible to say what exactly belongs where because every family has members
# Processed 15/179 samples...
# We have 2 people who want to go into the theater. They both want to watch a film, but we only know one of them wants to go into the theater. If there is more than one person wanting to enter a building then it would not be possible to classify what they were doing.
# Processed 16/179 samples...
# The sentence “A person waits” entails “The person gets his sandwich”. Therefore, if we are told someone waited, then there was probably some kind of exchange. For example, perhaps they ordered something and it took them 30 minutes.
#
# Sentence Analysis:
#
# “Person”: Person refers to the subject (“John”) in the main clause.
#
# “Gets”: Gets means getting or obtaining
# Processed 17/179 samples...
# I'm not sure if there are any other types that could be used to classify this.
# Processed 18/179 samples...
# The two characters have similar clothing, facial features and body language. They also seem to be friends.
#
# Outcome: The woman is laughing with her friend
# Processed 19/179 samples...
# The first premise suggests that there must be at least two people present; however, since only one individual is shown on screen with no other persons nearby (and since we are told he "is alone" near the beginning of the video), it's unclear if this assertion can possibly be true.
#
# Explanation:
#
# The narrator begins by introducing a group of individuals gathered together outside. He then
# Processed 20/179 samples...
# I believe that there are no dance moves or choreography to explain. This could be due to it being a pre-recorded video (e.g., a live performance at a convention) and so not having any actual dancers on set.
#
# This question was closed by @Bryson.
# Processed 21/179 samples...
# the hypothesis asserts that a white dog would jump up when he saw his pet. The assertion is then used as evidence of the entailment relation.
#
# Example: If I say “I will go home after dinner”, and you ask me why, my response might be something like “because I want to”. This sentence entails the claim ‘after dinner’ in which case it can also
# Processed 22/179 samples...
# The hypothesis specifies that the man plays golf and he does not mention what kind of game. Therefore, we assume it's probably one of these games:
#
# • Bowling
# • Baseball
# • Pickleball (the only sport I know how to play)
# • Tennis
# Processed 23/179 samples...
# I think there are 3 ways to get the entailment here.
#
# 1) The man in the photo could be thinking about what might happen when they do their laundry together, or
# 2) The man in the photo has not been shown any pictures of himself and therefore does not know if he looks funny with a camera pointed at him or not.
#
# In either case,
# Processed 24/179 samples...
# the man has a mental age of 84, and so cannot understand why he should not be laughed at. He also seems more interested in watching what happens than participating himself.
#
# This scenario demonstrates an example of an inconsistency between the person's knowledge about how things work (the "hypotheses") and their behavior ("classification"). The fact that they are laughing at themselves suggests that
# Processed 25/179 samples...
# the event is an entailment of another event, so it would make sense that they are related.
# Processed 26/179 samples...
# This is an instance where the conclusion does not necessarily follow from the premise. It's possible that if there were more people watching, they would have seen it too.
#
# Inference Reasoning
# (1) The trick was done by one person. (2)
# If 2 then 3
# We can infer that the trick was performed by only one individual.
#
# ## Classify
# Processed 27/179 samples...
# The hypothesis states that if $A$ and $B$ are two events such that $\text{Pr}(A) = 0$, then $A \Rightarrow B$. This leads to the conclusion that there exists no event where we can say with certainty whether or not $C$ will occur.
#
# Solutions:
# 1. $P(\textit{Man}) > P
# Processed 28/179 samples...
# The hypothesis states that two objects move in opposite directions. The premise shows that there is at least one object moving in each of those directions.
#
# Examples:
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# I am driving to work on Monday morning; my car runs great (hence no problems).
#
# A) I will be late because traffic was heavy.
# B) My
# Processed 29/179 samples...
# The driver of the taxicab is moving towards the client (i.e. forward), and he does not seem to be doing anything unusual or unexpected. Moreover, there are no obvious differences between what happens at the intersection and how it would happen elsewhere.
#
# # 2/5
# Processed 30/179 samples...
# the singer is not clearly identified. The woman holds up a white flag and does not have an obvious relationship to either of the other women.
#
# A more accurate description would be:
#
# The song that she's performing is called "I Will Survive" by Gloria Gaynor, and it was released in 1978 as part of the soundtrack for the film "Grease".
#
# It
# Processed 31/179 samples...
# There was no evidence that the farmer with the red shirt and blue jeans were actually doing anything to the machinery. Instead, they appear to be simply standing around waiting for their friend who was supposed to work on it.
#
# ## 2 thoughts on “John Deere”
#
# 1. If you want more information about entailments check out this page http://www.cs.ucl.ac.uk
# Processed 32/179 samples...
#
# Processed 33/179 samples...
# It seems to me that the first sentence in the context does not imply anything about what she is doing. If you read it as "I'm putting down some words," then yes, I guess so.
#
# If we're talking about semantics and logic (and we are), there's an interesting issue here. There aren't any grammatical rules that would force us to say that
# Processed 34/179 samples...
# We have evidence that if an event happens, then it’s entailed by another. Since we know there was something to slide on (the slippery floor), it follows that whatever happened must be wet.
#
# The fact that the baby did not get wet does not change our analysis; it just means that they are more likely to do so in the future than with other types of flooring
# Processed 35/179 samples...
# The premise implies that there was a child, who had to have been present. In order for an entailment to be validly derived from premises it must imply all of its conclusions.
#
# Conclusion: At least one person was on the slide with the baby
# Processed 36/179 samples...
# It's a simple motion, it doesn't change direction too much, and there are no changes of state.
#
# The question is about swinging on a playground. I'm told that "when you're swinging on the swing it feels like your going up." To me this seems more likely to be an acceleration (you can feel the force pressing down harder than usual) rather then a
# Processed 37/179 samples...
# The hypothesis entails that the subject is having a drink.
#
# Example:
#
# Premise:
# A man with glasses and white hair sits in an armchair on top of a table. He holds his head up, looking into a mirror as he puts makeup on his face.
#
# Conclusion:
# The man wears glasses and has white hair.
#
# This reasoning will be evaluated using the following criteria (in order
# Processed 38/179 samples...
# In English, we often use words like "try" or "chose", when something isn't very clear. This word could be used to describe anything that can help us make our decision.
#
# Examples:
#
# Try finding my keys
# Chose a pen
# Choose your favorite color of crayons
# Processed 39/179 samples...
# The author describes her as making something. It could be made from cloth.
#
# Example: 1) I'm going to make an omelette (a type of dish). This entails that I have some eggs, cheese and perhaps some other ingredients like onions or bacon.
#
# 2) My grandmother has always been able to sew perfectly straight lines. That means she can do things like
# Processed 40/179 samples...
# The hypothesis can be proved by the premise. If we take out one of them, the other becomes false.
#
# Description: I'm washing my steps (a) and a pool (b).
# Processed 41/179 samples...
# The premise does not mention who is doing the cleaning, but it is implied that they are a member of the same team as the people working on the pool. This makes sense because the purpose of having someone clean their steps in the first place is to prevent dirt and grime from building up over time.
#
# Conclusion 1:
#
# The conclusion follows logically since both premises imply that there
# Processed 42/179 samples...
# the premise is contradictory, so there's no way that it can be true.
#
# This seems like an unusual example of a contradiction. The premises are not logically inconsistent and I don't see any obvious flaws in the reasoning or logical structure used to reach these conclusions. However, my brain just doesn't seem able to make sense of them as anything other than contradictions at all moments.
# Processed 43/179 samples...
# The hypothesis specifies that the subject (the rider) is “on” something. This entails the predicate (“is”), which says they are somewhere, not just anything.
#
# For instance, if I were to say, "A man was walking along the road," it would be incorrect because there could be many roads, and only one path he walked down. If someone said, '
# Processed 44/179 samples...
# This image is clearly showing something on the ground and it could be interpreted as a child trying to look at the bicycle. The reason that I chose the "Bike" hypothesis was because there are no other bicycles in the scene.
#
# My conclusion was based off of my observations but not supported by any evidence given in class.
# Processed 45/179 samples...
# I believe that it is a fact based on my personal experience. If you have never seen or heard about any other type of animal catching fish then they may not be classified as such.
#
# Explanation:
#
# I saw this scene on YouTube (https://www.youtube.com/watch?v=0yC5M8i4uJc).
# Processed 46/179 samples...
#
# Processed 47/179 samples...
# I am not sure how to classify it. It is a bit abstract, but that's because we haven't learned about classifications yet.
#
# Solving for X:
#
# $$\text{X} + \frac{\sqrt[3]{\pi}}{2}\approx 15,$$
#
# where $$\text{X} = \text{number of hot air balloon launches in
# Processed 48/179 samples...
# This is not a story. It's just the premise.
#
# ### Other stories with this premise:
#
# Men and women walking across street
# Processed 49/179 samples...
# The number and types of musical instruments is high, there are some specific ones like piano, guitar etc. but not too many.
#
# This category can be further divided into two more categories:
#
# * Musical instrument
# * Musician
# Processed 50/179 samples...
# The hypothesis has to be true. (That's the definition of entailment.)
# Processed 51/179 samples...
# There are no other similar examples to compare against.
#
# Discussion:
#
# The premise is true. It could be any number of things but there’s nothing else like it in history that I can think of.
# Processed 52/179 samples...
# Because we are in an open field and there is no clear separation between us. There could be some kind of interaction.
# Processed 53/179 samples...
# The word "walk" has many meanings. I chose "walking".
# Processed 54/179 samples...
# The fact that the woman's hand covers her mouth makes it very likely that she is speaking.
# Processed 55/179 samples...
# No obvious reason.
# Processed 56/179 samples...
# This hypothesis was built on the premise that these three people were in front of a camera. So, I concluded that they have to be holding a camera.
# Processed 57/179 samples...
# The first hypothesis is false. If the five men were standing, then there would be three of them and two of them; if they had been standing on chairs, then one of each group would have to be seated.
#
# Example: A man wearing a green tie with blue stripes sits in front of a whiteboard, holding an apple, while he reads "I am going to
# Processed 58/179 samples...
# the performance can be seen as a consequence of one event (the street) which leads to another.
# Processed 59/179 samples...
# The hypothesis describes what happens when you do something, so it should be classified as an action.
# Processed 60/179 samples...
# The first man runs to home plate, which would make him the runner. It could also be said that there are two runners (the first man plus another who follows behind).
# Processed 61/179 samples...
# If the hypothesis is true, then there will be no conflict. So if they're all on one side of a table that's not being disturbed by anyone else, it would make sense to think they'd just sit down without any problems.
#
# Example:
#
# If you have two people who want to eat dinner in your kitchen, but you don't give them enough space to separate from
# Processed 62/179 samples...
# The hypothesis is the premise and its negation, so it entails both of them. However, if we were to try to prove that there’s no food fight in our hypothetical world (i.e., if they’re not throwing tomatoes), then either one would be false.
#
# Conclusion: There is a food fight happening somewhere on Earth right now.
#
#
#
# It appears as though there's currently
# Processed 63/179 samples...
# The two statements are entailed by each other. If you're standing in line to get something, then you don't have anything else on your mind (unless it's waiting until the next round). So if I'm standing in line to order food at an Indian restaurant, I must be hungry.
#
# Inference from premises to conclusion:
# If I am standing in line for both
# Processed 64/179 samples...
# This is an example of the paradox of self-reference, which states that if you can prove that it's impossible to prove your own impossibility, then what you're saying isn't actually true.
#
# It also illustrates some other basic rules of logic:
#
# • If $p$ implies $q$, and $q \implies p$, then $p$
# • If there exists no
# Processed 65/179 samples...
# The hypothesis is that they're having an argument. This can be seen by their facial expressions, but also because of some words they use.
#
# This reasoning is wrong. It's not contradictory to say "They have an argument" when someone says it with one face or another.
#
# You've just given us two possible meanings of "having an argument". One meaning would be like "
# Processed 66/179 samples...
# I think it's too ambiguous to be classified as either. It might fit both categories.
#
# Sentence 1: "This is my next big business idea, which will make me rich."
#
# Sentences 2-3: "I want to buy an island off of Bali. And I plan on getting rich doing that."
# Processed 67/179 samples...
# The premise is false. It can't be true that there are two people in the world.
#
# Explanation of reasoning:
#
# If we take out all possible combinations from 2, then you get a total of (0) options. If we assume one person was inside and another on the street, but they didn't interact at any time during their day, then these would be counted
# Processed 68/179 samples...
# The first person is the customer, and the second is a server. These are not clearly distinct entities.
#
# Justification:
#
# This reasoning seems correct because the store owner cannot be both on the ice cream stand and also serving customers at the same time.
# Processed 69/179 samples...
# In order to classify as a sentence, it must be able to be completed by an agent. This means that the child can hear or see something and complete their own sentences.
#
# Examples of words not included in this hypothesis:
#
# This example includes all of the above features but does not include any word which would cause it to fail the test for entailment because the child could not
# Processed 70/179 samples...
# (1) A man is a person; thus, it can be inferred that he makes food.
#
# Conclusion: The two men make food.
# Processed 71/179 samples...
# The two characters have a mutual relation (friendship) and one is not an object.
# Processed 72/179 samples...
# The man is not explicitly described, but by implication he seems to be a lone wanderer. Also it's implied that he wanders into a cloud.
#
# Conclusion: I'm going to walk around until something happens and then go back home
# Processed 73/179 samples...
# The scene is just one of many that I've seen on my travels, so it's not particularly memorable. However, the location seems to be an open plain with little or no trees. It could also very well have been taken somewhere else.
#
# I had never thought about how much more difficult writing a script would become if you didn't have any characters to talk to each other
# Processed 74/179 samples...
# This sentence has a noun phrase that functions as an antecedent and the pronoun it refers to.
#
# Explanation:
#
# The person who looks like she’s wearing lipstick is most likely going through something difficult or emotional. The fact that her lips are slightly parted suggests that there may be some type of communication taking place between her and others around her, but we’re not sure what exactly
# Processed 75/179 samples...
# The premise describes the subject of the story, and that's enough.
# Processed 76/179 samples...
# The premise contradicts itself.
# Processed 77/179 samples...
# The hypothesis describes how many people are present, while the premise describes what they look like. Therefore, it must be entailed by the premise.
#
# Explanation
# The class “man” has no properties associated with it; therefore, we can conclude that there will always be some person(s) who fits into that description.
# We need to prove that all men fit within our given criteria
# Processed 78/179 samples...
# The hypothesis describes an action, and we can infer that the subject performs it. There's no way to know whether he has any other shoes on or not.
#
# Conclusion: No conclusion
# Processed 79/179 samples...
# The title of the ad is confusing. It could mean that Hitler was on water skis, but it seems more likely he was just riding a jet ski.
#
# I'm not sure I would call this an example of 'contradiction', since both statements are true - at least if you accept the assumption that people can be on water-skis and still ride motorcycles (although
# Processed 80/179 samples...
# The question asks to classify an object as either "neutral" or not, so we can rule out any possible answer that is not in between those two options.
#
# This video explains how to do it.
# Processed 81/179 samples...
# The narrator states that there was no other sound or movement. Therefore, they can infer that someone else must be doing it.
#
# Evidence:
#
# • No additional information about who does the bathing
# • The child has been removed from his/her mother and is therefore not being held while he/she is being washed
# Processed 82/179 samples...
# If we can show that every sentence in English entails another sentence, then there is no need to say anything about whether or not one statement logically implies another.
#
# Sentence 1:
#
# If I go hiking tomorrow, my wife will want me back by dinner time. (I have to be home before dark)
#
# Sentence 2:
#
# If I don't finish the book tonight, I'll
# Processed 83/179 samples...
# This can be done by considering the premises and their implications.
#
# Explanation:
#
# The hypothesis says that there will be no folding of the piece of paper. However, if it is not folded then there won't be any reason to assume that there would be someone else doing something else at the same time as him. The conclusion follows from both the premise (if he doesn't fold the
# Processed 84/179 samples...
# This is a soccer-related video clip. The description of it includes "soccer", so I think that entailing something about a soccer related topic makes sense.
#
# I'm looking forward to your comments!
#
# • @Lambie - you've got all sorts of things going on here, but what I'd like to focus on at present are the relationships between these terms and their
# Processed 85/179 samples...
# It's possible that there are multiple artists behind these paintings, and they have different prices. Or maybe the guy is just an artist himself.
#
# Note that we did not make any assumptions about how likely it is to see a painting at some point in our lives (e.g., probability distribution), nor were we interested in assessing its credibility as evidence for artistry or other properties of
# Processed 86/179 samples...
# I don't know, but it seems like something that might be true. And if so, why not?
# Processed 87/179 samples...
# the two statements are similar in meaning.
#
# Classifiers used to classify "entailment" include:
#
# • If $$p$$ entails q, then we write p --> q. This means that if p is true and it's always possible that q could be true, then p must necessarily imply q (i.e., $$(\neg \lnot q) \rightarrow (\
# Processed 88/179 samples...
# It looks like they are both squatting. There's no other evidence.
#
# Conclusion:
#
# • 0
# Contributors:
# PierianDialectic
# Processed 89/179 samples...
# The presence of one person (the man on the left) implies that there will be another person. The fact that they’re both in an awkward position suggests it’s unlikely that either or both of them are alone.
#
# Analysis:
#
# The reasoning here uses the entailments between “two people” and “one person”, as well as between “a single person squatted” and “
# Processed 90/179 samples...
# The projection screen and the people are both objects. They have properties, such as color, shape, etc.
#
# The audience can be considered an object with its own unique set of characteristics (e.g., colors). This classifies it from being part of the scene or stage. In general, I would say that if you were given two different pictures of the same event, one
# Processed 91/179 samples...
# The hypothesis says that the man is watching TV. But we know he isn't because we can see him with his eyes closed.
#
# Assumptions:
#
# • Man (M) has eyes and ears
# • M is watching TV
# • M's head is above the projection screen
#
# Conclusion:
# The following are true:
# 1.M does not have an eye on the side of their
# Processed 92/179 samples...
# The premise of the hypothesis states that an event occurs. This implies there must be something happening at the time, which means it cannot occur without some context.
#
# Explanation:
#
# A person presents information about their research on a particular topic in front of people (e.g., a class or audience). The speaker's body language and facial expressions may convey certain things like enthusiasm, frustration, humor
# Processed 93/179 samples...
# The phrase “a little boy” refers to the person who has just left, and the fact that he/she jumps out of the house.
# Processed 94/179 samples...
# It is a very specific kind of entailing action. Most actions do not involve any force or violence to anyone, but it does.
#
# Notes:
#
# • The original version (in the game) was quite different from what I ended up with in terms of structure and grammar; here I just took out most of the superfluous stuff that doesn’t really add anything meaningful and left
# Processed 95/179 samples...
# The premises contain three distinct elements, and the hypothesis contains only one element. If there were more than one element present in the hypothesis but none of them matched any part of the premise (or vice versa), we would not classify it as an entailment.
#
# Proof:
#
# 1. Premises
# 2. $x \in S$ where $S = \{a,b,c
# Processed 96/179 samples...
# The hypothesis, while not explicitly stated by any of the sentences involved here, does include an entailment relation between "a couple" and a "man."
# Processed 97/179 samples...
# I would call it an entitle, because it contains all of those words.
#
# My hypothesis was correct. It's not that hard to find these things on YouTube if you know where to look!
# Processed 98/179 samples...
# This is an example of entailment. In this case, it means that "boy" entails "looks".
#
# Example sentences:
#
# 1. "He's looking so sad." (entailment)
# 2. "I don't know if she likes him or not."
# 3. "He was talking to her in front of everyone."
#
# Inference rules:
# • Entailment
# Processed 99/179 samples...
# The hypothesis asserts that the man is at a car dealership. That assertion can be inferred from his being in a vehicle with a license plate and the fact he's holding an automobile magazine.
#
# Conclusion: At least one of these two premises are true, hence the conclusion must also be true.
# Processed 100/179 samples...
# The hypothesis entails that there exists an object in which the musician plays. This object must be described using the noun "instrument".
#
# Analysis:
# Processed 101/179 samples...
# The hypothesis and premise both contain "man" as their first noun.
# Processed 102/179 samples...
# A woman walking with two other women is not a person.
#
# Explanation:
# The three women are walking down the street. They have just walked past an office building and they are now heading toward it, whereupon one of them turns left at the end of the block to get directions from her phone. The first woman stops before she gets to the corner because she wants to take pictures
# Processed 103/179 samples...
# The assumption of the hypothesis is that there must be some sort of connection between them, and their expectation.
#
# Conclusion (or conclusion(s)):
#
# I'm not sure if I've used "expect" correctly.
# Processed 104/179 samples...
# it is impossible to be in one place and the other.
#
# Proof:
#
# 1. One person cannot wait on a platform because they must board the train, so that means she can only stand somewhere else
# 2. The second person could not have waited on a platform because if he did then his friend would need him to do something (which was ruled out), but instead he boarded
# Processed 105/179 samples...
# I feel like the facial expressions are pretty similar, but there's just something about it that makes me think they're both people.
# Processed 106/179 samples...
# It seems likely that there is at least one woman. This hypothesis has not been proven yet.
#
# Conclusion: The conclusion of our reasoning can be expressed as:
#
# • $A$ and $B$ read books
# • Both A and B have clothes on
# • No woman in the book reads a book
# Processed 107/179 samples...
# Each elephant carries at least one person and thus they are all entailed.
#
# Conclusion 1:
#
# Conclusion 2:
# Processed 108/179 samples...
# I can infer the existence of the turtle because we know that turtles live in water and swimmers are not able to survive without water.
# Processed 109/179 samples...
# The description of the premise (a man with a beard skateboarding) entails that there is something out on the street. Also, if there were no skateboarder or no bearded person then it would not make sense to say "there was" so therefore we can infer from here that there are both.
#
# Conclusions:
#
# 1. There is a man skating
# 2. There
# Processed 110/179 samples...
# The text is written to be enjoyed by children, but it’s not explicitly aimed at them. It doesn’t contain any specific content that would appeal specifically to children.
#
# The story reads like it was intended for kids of all ages (but especially younger ones). There are no explicit warnings or age restrictions; there is just enough information here and there to make the reader think “Oh
# Processed 111/179 samples...
# We don't have any information about who they are or what their job may be.
# Processed 112/179 samples...
# The word "Coca" is used to refer to Coca-Cola. Since we know that it's a beverage called "cola", then by inference we can assume that there exists an object named coke.
#
# Analysis of the data
# The 3 instances are all similar but different from each other (the only difference being their clothing).
# We could have created another hypothesis about the meaning of
# Processed 113/179 samples...
#
# Processed 114/179 samples...
# The title of this video is "Eyes on You" by Patti Smith, from her album Horses. I am assuming that we can say that if someone is looking at you then they are probably seeing something about themselves.
#
# The hypothesis is correct because when watching Eyes On You (by Patti Smith), it looks like she's staring directly into the lens as if she
# Processed 115/179 samples...
# The child is very young, so we cannot tell much about their life. They are not wearing any clothes that would identify them as being of specific gender.
#
# Conclusions:
#
# 1. No conclusions can be drawn from this image at all (i.e., no information whatsoever).
# 2. This is most likely a photograph taken during World War I or II; based on the date stamp
# Processed 116/179 samples...
# Because the hypothesis and conclusion are about a boy, it must be that he is blowing bubbles.
# Processed 117/179 samples...
# I would have guessed that the child was too young to understand what it meant, and therefore just wanted a play area. However after some thought about how they were interacting I decided that maybe they had realised something different.
#
# Explanation:
#
# When we are in our childhoods, there is usually no problem understanding or accepting things as reality. We believe everything we see around us is real.
# Processed 118/179 samples...
# If you have three people and they're all holding something, then there's at least two things. So it can be considered an entailment.
#
# # 2 thoughts on “Entailment”
#
# 1. I think that if you know that x = y -> z is true, then knowing that x = y & z is false should not change your opinion about whether or not
# Processed 119/179 samples...
# The hypothesis and premise both assert there is only one person. However, they contradict each other by saying that two people could be standing near the same fish.
#
# Why it's not true:
# There can be more than 1 person at once but no 2 persons at once
# For example, you have 3 friends who go out together, and all of them are going swimming
# Processed 120/179 samples...
# The hypothesis says that the object in front of him (the toy) is moving. This movement causes the dog to chase it. It seems reasonable, then, that if he catches up with something and starts following it around like a puppy, he would be classified as having chased or been chased by an animate object.
#
# Definition: "A definition is a statement used to explain how
# Processed 121/179 samples...
# The hypothesis makes sense because if you hold it up to your eye, there's nothing there. There is no "animal" and therefore it can't be asleep.
#
# Explanation of why we chose that particular example:
#
# The fact that in the video he holds up an object as though it were something else (the toy) but then moves it so fast that it disappears from view suggests
# Processed 122/179 samples...
# Both the subjects have a clear relationship to each other. They are in one location and both appear to be working.
#
# Inference from premises:
#
# 2 women doing something together, which is more common than 1 woman doing it alone (see “Commonness of situations”).
# Two people who do similar things may end up being closer friends or acquaintances as they get older (this
# Processed 123/179 samples...
# It was a simple observation. I did not have any other information to support my hypothesis.
#
# Conclusion: If it's calm, then there are no waves or ripples on top of water. Therefore, if you look at two points on the surface, they appear perfectly parallel and straight (or nearly so). This would be impossible if there were waves on the water.
# Processed 124/179 samples...
# 1. The pose is not intended to be held long enough to harm the person, which would include injury from extended muscle tension.
#
# This reasoning has been argued in favor by:
#
# • Bhanu Pratap Singh (2020-10-02), who describes how some poses can cause injuries and explains why this does not apply here.
# • Anjali Gop
# Processed 125/179 samples...
# Given that there is no other information, we classify these as performing an action.
#
# Example 1:
#
# In Example 2, if you say "the girl dances" then your assumption about what she's doing (dancing) would be true. But to make the assertion "she performs an action", I need to know which kind of action she performed; so it should have
# Processed 126/179 samples...
# All of these cards match, so they must be identical. However, that is not enough to determine their type.
#
# Solution 1 (matching all four): $A$ and $B$ match each other, as do $C$ and $D$. That means there must be some common property between $A$, $B$, $C$, and $D$: let's
# Processed 127/179 samples...
# The context does not state where the "garbage" came from. Also note that there was no reference to the location or source of the trash can.
#
# Conclusions
# The students are either going through an episode of misbehavior during class time, causing them to be punished by being sent outside for recess, or they are simply making sure everyone gets back inside after they have been
# Processed 128/179 samples...
# This scenario could be interpreted as an instance where the child is playing "Hide and Seek" or some other similar game. However, I'm not sure what the actual context would look like.
# Processed 129/179 samples...
# The premise is true when the other part of the sentence (the hypothesis) isn’t present.
# Processed 130/179 samples...
# Contradiction
# Example sentences: (a) I can't sleep. - "I am not sleeping." If the child is awake, then he cannot be sleeping.
#
# This reasoning technique requires three premises and one conclusion:
#
# • Premise 1: The child is awake.
# • Premise 2: The child is looking out of the door.
# • Conclusion: The child
# Processed 131/179 samples...
# The sentence has two premises. It seems to me that the second premise must be true because if it were not, then there would only be one possibility and that means there could have been no door in the first place.
#
# Example sentences:
#
# I am going home now.
# That's my house!
# It was an old castle with high walls!
#
# There are 2 doors leading into the
# Processed 132/179 samples...
# The hypothesis is an assertion about something that does not exist. It's false, so it can't be classified as true.
#
# Description:
# This image was taken from http://www.kidzworld.com/article/1045-the-batman-and-2-clowns-in-a-cage
# Processed 133/179 samples...
#
# Processed 134/179 samples...
# The first premise states that a man sits, and from this it follows that he also sits at some time. This relation between two statements can be expressed by means of an entailment arrow.
#
# The following diagram illustrates how to use the entailment arrow:
#
# $\text{A}\vdash \text{B}$ $\Rightarrow$ $\text{A}$
# $\Rightarrow$ $\
# Processed 135/179 samples...
# This image was classified as "neutral" because it does not contain any overt signs that would indicate either racism or sexism. In addition to the person being black and male, there are no other obvious indicators such as facial features, clothing style or hair color.
#
# This hypothesis has been tested against all images uploaded to Wikimedia Commons between January 1st, 2009 (inclusive)
# Processed 136/179 samples...
# The man is lying on his stomach. His head and shoulders are facing away from us.
#
# Proofs:
#
# 1) 2 + 3 = 5
# 2) 6 - 4 = 2
# Processed 137/179 samples...
# If the hypothesis was true, then we could expect that if the animal were white, it would reach for the ball by using only one paw.
# Processed 138/179 samples...
# The context suggests that it's raining. If it's not raining, then there are no puddles.
#
# The hypothesis states an entailment relation between "It's raining" and "There are puddles." Therefore we know that the statement is true in the case where "it's raining."
#
# 1. What do you think about this reasoning?
# 2. Do you see any problems
# Processed 139/179 samples...
# The boys' gender, ages and location indicate they could be middle school students. However, I have not found any sources indicating what age or grade level would correspond with each of these categories.
#
# The children's clothing indicates their socioeconomic status as well (although all four wear hoodies). This also correlates with them being in grades 8-11.
#
# All four share an interest in
# Processed 140/179 samples...
# "Dinner" is a type of meal, which implies that it's an event. However, since we are dealing only with human beings, not animals, they cannot be considered as eating food.
#
# We can conclude that there is no relation between these two terms.
# Processed 141/179 samples...
# I have never heard of an actual person dressed as a horse or goat. This seems like the kind of thing someone would make up in order to trick others.
# Processed 142/179 samples...
# This is an example of two people looking at the same thing, so it's entailed by "Two people".
#
# A man stands outside on a street corner. He is holding up his hand to say hello.
#
# Premise 1:
#
# The man is holding his hands outstretched.
#
# Conclusion 2:
#
# The man has raised one or both of his arms.
#
# This premise-
# Processed 143/179 samples...
# I have never seen the movie, but based on what little information is available about it online (like plot summary and cast) seems like something of a parody. It's also very weird that there are people who actually dress up as zombies or pirates while shopping.
#
# My initial guess was "parody", because they were all wearing clothes with some kind of zombie/zombie-like motif
# Processed 144/179 samples...
# I'm going with it.
# Processed 145/179 samples...
# This hypothesis can be derived from the evidence presented. The building was clearly not made out of glass, which would have been very obvious to all present.
#
# Explanation: All objects in the world that were built before 1950 are either metal or stone and therefore cannot be classified as "glass". If we consider how long it took to build buildings during different time periods, then we
# Processed 146/179 samples...
# the speaker is clearly talking about something they saw or heard and it seems like the listener knows what that thing was.
# Processed 147/179 samples...
# The piano is a classical instrument, and the French Horn (or more specifically the trombone) was created by J.B. Arban in 1836.
#
# Theorem
# If we have $n$ instruments of type $\alpha$, then there exists some $k \in [0,n]$ such that at least one of them can be used with any other given instrument if
# Processed 148/179 samples...
# The only other person in the video that can be considered similarly dressed is the woman, who appears to have just finished her shower. She also has her hands at least partially covered by towels.
#
# The narrator's facial expression does not change when he sees the first object.
# Processed 149/179 samples...
# I can see the man's hand, and therefore his arm. This is enough to know that he is standing still.
#
# • If you have a question about this article or any other, please post it on StackExchange chat room (not in comments).
# Processed 150/179 samples...
# The premise is about a group of people and one child runs in between them. The hypothesis states that they will all be able to see each other.
#
# Conclusion: This conclusion follows logically because the premise entails the conclusion. If it was not true, then we would have a contradiction.
# Processed 151/179 samples...
# This is an entailment because we can derive "animals" from the premise. The statement also contains a quantifier, which means that there must be at least one animal in the herd.
#
# This conclusion does not have to hold necessarily true.
# Processed 152/179 samples...
# I am not sure if these two images show the same event. It seems like it is different animals, but perhaps they're just in different scenes.
#
# Image 1:
#
# Image 2:
# Processed 153/179 samples...
# The verb ‘walk’ indicates that they are not only walking, but also on their way somewhere. This means that it’s possible that there is some kind of activity (e.g., going shopping) happening in the garden.
#
# Inference from premises:
# The sentence can be interpreted as asking whether or not two people are actually doing something while walking around.
# Processed 154/179 samples...
# The hypothesis must be true if the premises are true, and because both hypotheses include a water reference to mean that they must be true. Therefore, we classify it as an entailment.
#
# • What did you learn from your reasoning? I learned how to apply a conditional inference rule (hence my answer) and also about what kind of statement can be classified as entailing another
# Processed 155/179 samples...
# I believe that dogs are not necessarily animals. In fact, there could be many more types of animal than just mammals. However, we can say that most (all?) mammal species have hair on their bodies.
#
# Definition:
#
# An animal is any living thing with cells and a nervous system that makes it able to move around.
#
# Explanation:
# I think we’re mostly referring
# Processed 156/179 samples...
# The person's body is still moving when they enter into motion. Also, their legs are extended.
#
# Conclusion:
# The person will be able to get out of the water before drowning if they jump backward while standing on one foot.
#
# If you have an example that differs from what I've written above please let me know!
#
# • This question has been answered by another user and should not
# Processed 157/179 samples...
# The hypothesis says that a woman will jump in the air if it’s sunny. So we can reason that when there are clouds outside then the person won’t be able to see the sun, so they’ll stay inside.
#
# Conclusions:
#
# 1. If there aren’t any clouds (or rain), then you shouldn’t go out in them because you might get hurt or even die
# Processed 158/179 samples...
# The scenario implies the girl must be alone. She's sliding down a slope, and it appears that she has to travel downhill all the way from home until her destination.
#
# Conclusion 1:
#
# The hypothesis holds because there are only two possible interpretations of this scene:
# * In Scenario I, the girl cannot reach any place except for her own house
# * In Scenario II, the
# Processed 159/179 samples...
# The slide has the color of its base. It's also colored.
#
# Explanation:
#
# The slope here matches with that which will be used to classify it as entailed or not, if we assume that "the child" (of the class "girl") does indeed exist and that she exists at some time between 3 PM and 4 PM.
#
# The fact that "it's
# Processed 160/179 samples...
# The hypothesis is that they're playing football, because of the color scheme.
#
# Comments:
# 1. Why do we use "football" rather than just "soccer"?
#
# 2. Is it possible that some people would think of the same thing as me (e.g., I said something about a man being on top of his girlfriend's head), but not be confused by my actual
# Processed 161/179 samples...
# This scenario entails that a dog will jump out of its enclosure and run through an open space. Dogs are known to be able to leap high, so it is reasonable to assume that this would happen.
#
# Conclusion: The conclusion should be "A dog jumped from his cage and ran away."
#
# Premise 1: $D$ can climb over walls
# Premise 2:
# Processed 162/179 samples...
# This is an example of the use of entailedness (and, in particular, entailment by definition) as part of a proof. In this case, we are using it to show that one proposition entails another.
#
# What about other classes?
#
# Is there any difference between these two examples? Are they similar or different?
# Yes, I think so. The first example shows what
# Processed 163/179 samples...
# This is an instance of the "power drill" family, which also includes such things as wrenches, screwdrivers, hammers, etc.
#
# Description:
#
# This is one example of a tool that has many uses.
# Processed 164/179 samples...
# According to our previous hypothesis that there were three people present (see #2), we can assume that all of these people must be outdoors. We have also established that all of those who are outside do not listen to each other; therefore it's impossible that they're inside.
#
# Proofs:
#
# Theorem 1:
# All listeners are outside
# Let $L$ denote a listener
# Processed 165/179 samples...
# the statement "I am standing in front of a house" implies that I am not. Hence, if an object is inside something and it's not me then we can conclude that there are two objects.
#
# What does the sentence mean? I'm trying to understand what is being said here.
# Processed 166/179 samples...
# This hypothesis can be verified by asking "Is the guy in blue clothes sitting on the bench?".
#
# If we were to ask, "What is he doing?", then I would say that there's no way of knowing without seeing him. If someone says they are going into work, but doesn't get up and leave their house or take off their coat, it could mean many
# Processed 167/179 samples...
# The phrase "looking" in the hypothesis implies that there are two events happening at once. However, if we take out "look," it becomes clear that only one event happens simultaneously.
#
# Source 1: "Brushing my teeth." https://www.youtube.com/watch?v=Kx2V4J3hT9o&t=5s
# Processed 168/179 samples...
# The second player must be standing because he's not in contact with the first, so there can't be more than 2 people.
#
# Rules used to reason about premise: no assumptions
# Processed 169/179 samples...
# It could be a new baby or it's just being messy.
#
# Conclusion: The baby has been born.
#
# Explanation of reasoning:
# Processed 170/179 samples...
# The person is smiling.
# Processed 171/179 samples...
# The hypothesis says that she's looking out to see her husband. Since it appears like he doesn't know what's going on, we assume that there must be something wrong with him.
#
# Explanations:
#
# 1) She is probably being abducted by aliens or having a dream (she may have been dreaming about an abduction)
#
# 2) He has gone missing and is in some kind
# Processed 172/179 samples...
# (1) The horse is in the same class as other animals, which includes mammals. It follows that all the animals are mammals.
#
# (2) All horses and donkeys have four legs, so they are both mammals. But some humans also have four limbs, while others only walk or run. Therefore, there must be two types of mammal; one with four limbs
# Processed 173/179 samples...
# According to the "Law of Excluded Middle", if a proposition can be true or false (or neither), then it cannot both be. This applies here because either she's not sleeping at all OR she is.
#
# Explanation:
#
# In order to get into bed I have to open my wardrobe first.
#
# If I don't open my wardrobe, then I'm still going to need to
# Processed 174/179 samples...
# I think the premise is intended to be taken as entailed. If you do not believe it is so, then there are at least two ways of interpreting the sentences (and their negations) that make them false.
#
# 1. There exist at least 2 men who wear a hat
# 2. There exists exactly 1 woman wearing a hood.
#
# In case (a
# Processed 175/179 samples...
# The word "man" has both an animate and an inanimate meaning. It's hard to know what the inanimate interpretation means, but it seems like a person could be seen as a microbe.
#
# The example I gave you was quite good - that one makes me think of something like 'a thing with two sides' which would make sense of your hypothesis (i.e
# Processed 176/179 samples...
# The hypothesis has no premises. It does not contain any logical implications that could be used to infer the conclusion from it.
#
# Explanation of my reasoning:
#
# The correct answer here is, “A man who is asleep and is sitting on a park bench”.
#
# To prove this statement, we need to find an object whose existence can be inferred based upon the given information. This means there should
# Processed 177/179 samples...
# the phrase "on his way" implies that he's going somewhere. The subject has already been identified as an Indian, and we can infer from context (the sentence structure) that it refers to someone who lives in India.
#
# This means that the first word indicates a location, not necessarily something one does with their time. This includes people, places, and things.
# Processed 178/179 samples...
# The noun 'indian' in the premise classifies as an adjective. We are assuming that it modifies another word, which can be considered "a thing".
# Processed 179/179 samples...

# %%
# --- Add Explanations to DataFrame ---
df_correct['model_explanation'] = model_explanations
print("\nFinished generating explanations.")
end_time = time.time()
print(f"Total time taken: {end_time - start_time:.2f} seconds")
# Out:
# Finished generating explanations.
# Total time taken: 281.66 seconds

# %%
# Display first few rows with the new column
print("\nSample results with model explanations:")
print(df_correct[['premise', 'hypothesis', 'pred_label', 'model_explanation']].head())
# Out:
# Sample results with model explanations:
#                                              premise  \
# 0  Two women are embracing while holding to go pa...
# 1  Two young children in blue jerseys, one with t...
# 2  A man selling donuts to a customer during a wo...
# 3  Two young boys of opposing teams play football...
# 4  Two young boys of opposing teams play football...
#
#                                        hypothesis     pred_label  \
# 0            The men are fighting outside a deli.  contradiction
# 1  Two kids in numbered jerseys wash their hands.     entailment
# 2             A man selling donuts to a customer.     entailment
# 3                              boys play football     entailment
# 4                            dog eats out of bowl  contradiction
#
#                                    model_explanation
# 0  Both of the premises imply that there is no ma...
# 1  The two numbers represent different teams. It ...
# 2  I have not yet written down all my thoughts on...
# 3  the definition is quite clear. The only questi...
# 4  The premise implies that the dogs are in the s...

# %%
# --- Save Updated DataFrame ---
print(f"\nSaving updated DataFrame to {output_file}...")
try:
    df_correct.to_csv(output_file, index=False)
    print("DataFrame saved successfully.")
except Exception as e:
    print(f"Error saving CSV: {e}")

print("\nScript finished.")
# Out:
# Saving updated DataFrame to results_correct_with_explanations.csv...
# DataFrame saved successfully.
#
# Script finished.
